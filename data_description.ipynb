# %%
# 2.1)
#Mit diesem Projekt möchte ich die ZeileResult welches ich selber 
#hinzugefüht habe vorhersagen für darauf folgende Länderspiele.

# 2.2)
#Diesen Auftrag habe ich in Excel bearbeite. Ich habe geschaut welches
#Team im Durchschnitt mehr Tore hat (heim oder auswärts)und ob das heim 
#Team am häufigsten gesiegt, verloren oder unentschieden gespielt hat.
#Ich konnte nicht viel mehr Informationen zu den anderen Zeilen bestimmen da es sehviele
#Kategorische Werte hat in meinem Datensatz. Jedoch habe ich neue Felder hinzu gefühgt
#nämlich "Result(home_team)" der gibt aus ob der heim-Team gesiegt(1) verloren(-1) oder
# unentschieden(0) gespielt hat, dies ist gut für die Vorhersage und dann gibt es noch 
#"home advantage" dieser Feld gibt an ob man heim vorteil hat (1) oder nicht (0).

# %%
# 2.3)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv("results.csv")

plt.figure(figsize=(8,5))
sns.histplot(df['home_score'], bins=20)
plt.title("Verteilung der Tore der Heimmannschaft")
plt.xlabel("Tore")
plt.ylabel("Häufigkeit")
plt.xlim(0, 10)
plt.show()

# %%
# 2.4)
# Ich habe die Felder home_score und away_score skaliert.
